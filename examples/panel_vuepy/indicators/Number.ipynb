# %% [markdown]
# # Number 数字指示器
#
# 数字指示器提供了一个值的可视化表示，该值可以根据提供的阈值进行着色。
#
# 底层实现为`panel.widgets.Number`，参数基本一致，参考文档：https://panel.holoviz.org/reference/indicators/Number.html

# %%
##ignore
# %load_ext vuepy
from panel_vuepy import vpanel

# %% [markdown]
# ## 基本用法
#
# `Number`指示器可用于指示一个简单的数字，并根据需要进行格式化：

# %%
# %%vuepy_run --plugins vpanel --show-code
# <template>
#   <PnNumber name="Failure Rate" :value="10" format="{value}%" />
# </template>
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3e18082e-ceba-4dbc-90ea-7867d35358bc'>
#   <div id="a3dbecc3-52d3-42f5-95f4-18369f61d9d4" data-root-id="3e18082e-ceba-4dbc-90ea-7867d35358bc" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## 颜色阈值
#
# 如果我们想要指定特定的阈值，在这些阈值下指示器会改变颜色：

# %%
# %%vuepy_run --plugins vpanel --show-code
# <template>
#   <PnRow>
#     <PnNumber
#       name="Failure Rate"
#       :value="10"
#       format="{value}%"
#       :colors="[[33, 'green'], [66, 'gold'], [100, 'red']]"
#     />
#     <PnNumber
#       name="Failure Rate"
#       :value="42"
#       format="{value}%"
#       :colors="[[33, 'green'], [66, 'gold'], [100, 'red']]"
#     />
#     <PnNumber
#       name="Failure Rate"
#       :value="93"
#       format="{value}%"
#       :colors="[[33, 'green'], [66, 'gold'], [100, 'red']]"
#     />
#   </PnRow>
# </template>
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='cc9bb777-6ea8-42bd-9c2c-a66223e0d248'>
#   <div id="a39cc595-5875-4278-adaa-29600e3a0be3" data-root-id="cc9bb777-6ea8-42bd-9c2c-a66223e0d248" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## API
#
# ### 属性
#
# | 属性名        | 说明                      | 类型                                                          | 默认值 |
# | ------------ | ------------------------ | -------------------------------------------------------------| ------- |
# | value        | 数字指示器的值             | ^[number]                                                     | —       |
# | colors       | 数字指示器的颜色阈值        | ^[array] 指定为元组列表，每个元组包含绝对阈值和切换颜色         | —       |
# | default_color | 如果未提供颜色阈值，使用的颜色 | ^[string]                                                  | black   |
# | format       | 接受{value}的格式化字符串   | ^[string]                                                     | {value} |
# | font_size    | 数字本身的大小             | ^[string]                                                     | 54pt    |
# | nan_format   | 如何格式化nan值            | ^[string]                                                     | -       |
# | title_size   | 数字标题的大小             | ^[string]                                                     | 18pt    |
# | disabled     | 是否禁用                  | ^[boolean]                                                     | false   |
#
# ### Events
#
# | 事件名 | 说明                  | 类型                                   |
# | ---   | ---                  | ---                                    |
# | change | 当值变化时触发的事件   | ^[Callable]`(event: dict) -> None`     |
#
# ### Slots
#
# | 插槽名   | 说明               |
# | ---     | ---               |
#
# ### 方法
#
# | 属性名 | 说明 | 类型 |
# | --- | --- | --- |

# %%
##ignore
import panel as pn

pn.extension()

# 简单示例
pn.widgets.Number(name='Failure Rate', value=10, format='{value}%')

# 颜色阈值示例
number = pn.widgets.Number(
    name='Failure Rate', value=72, format='{value}%',
    colors=[(33, 'green'), (66, 'gold'), (100, 'red')]
)

pn.Row(number.controls(), number.clone(value=60))
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f22c0748-a34f-4f1b-89a4-cfdd1b44da46'>
#   <div id="fff98ec6-f520-4326-bbc4-71e6750737e4" data-root-id="f22c0748-a34f-4f1b-89a4-cfdd1b44da46" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

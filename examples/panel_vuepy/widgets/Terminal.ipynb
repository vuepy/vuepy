# %% [markdown]
# # Terminal 终端
#
# 终端组件提供了一个与底层命令行交互的终端界面。它基于xterm.js，并通过WebSocket连接到服务器端的虚拟终端。
#
# 底层实现为`panel.widgets.Terminal`，参数基本一致，参考文档：https://panel.holoviz.org/reference/widgets/Terminal.html

# %%
##ignore
# %load_ext vuepy
from panel_vuepy import vpanel

# %% [markdown]
# ## 基本用法
#
# 创建一个基本的终端界面：

# %%
##ignore
import panel as pn
pn.extension("terminal")
terminal = pn.widgets.Terminal(
    output="Welcome to the Panel Terminal!\nI'm based on xterm.js\n\n",
    options={"cursorBlink": True},
    height=300, sizing_mode='stretch_width'
)

terminal
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='73dfda18-1bf4-4ff0-b217-a98afefa8f19'>
#   <div id="ec7cb225-9e21-46da-843e-f9b41b4d475d" data-root-id="73dfda18-1bf4-4ff0-b217-a98afefa8f19" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"88640ada-cfd4-45ff-a084-546e1ca3af6d":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"73dfda18-1bf4-4ff0-b217-a98afefa8f19"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"022fb52d-2d72-4fad-a884-226984f5d62c","attributes":{"plot_id":"73dfda18-1bf4-4ff0-b217-a98afefa8f19","comm_id":"a932a3687e8e47509f9012d9c0676475","client_comm_id":"e751a87302194e4a82d6d1bf5f462106"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"88640ada-cfd4-45ff-a084-546e1ca3af6d","roots":{"73dfda18-1bf4-4ff0-b217-a98afefa8f19":"ec7cb225-9e21-46da-843e-f9b41b4d475d"},"root_ids":["73dfda18-1bf4-4ff0-b217-a98afefa8f19"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Terminal(id=4693343968)

# %%
# %%vuepy_run --plugins vpanel --show-code --codegen-backend='panel'
# <template>
#   <PnTerminal
#     output="Welcome to the Panel Terminal!\nI'm based on xterm.js\n\n"
#     :height="300" sizing_mode='stretch_width'/>
# </template>
# <script lang='py'>
# from vuepy import ref
# </script>
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ab6ac313-309f-4ebd-b8ae-57931ee56670'>
#   <div id="c794374a-b500-4d05-988c-c16086b92217" data-root-id="ab6ac313-309f-4ebd-b8ae-57931ee56670" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1b62126f-b1fa-4b78-b562-d22d57ca6704":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"ab6ac313-309f-4ebd-b8ae-57931ee56670"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"452b6ae3-851e-496c-83e9-b088cfe4550f","attributes":{"plot_id":"ab6ac313-309f-4ebd-b8ae-57931ee56670","comm_id":"dfabd5c3f139484e9428a2f23fdf5d60","client_comm_id":"b7e43f6b26d145d8bc6e9c7275a3b4d4"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"1b62126f-b1fa-4b78-b562-d22d57ca6704","roots":{"ab6ac313-309f-4ebd-b8ae-57931ee56670":"c794374a-b500-4d05-988c-c16086b92217"},"root_ids":["ab6ac313-309f-4ebd-b8ae-57931ee56670"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# {"vue": "<template>\n  <PnTerminal \n    output=\"Welcome to the Panel Terminal!\\nI'm based on xterm.js\\n\\n\"\n    :height=\"300\" sizing_mode='stretch_width'/>\n</template>\n<script lang='py'>\nfrom vuepy import ref\n</script>\n", "setup": ""}
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Column(name='root')
#     [0] Column(name='body')
#         [0] Column
#             [0] Terminal(id=4693341328)

# %% [markdown]
# ## 指定命令
#
# 可以指定终端启动时要执行的命令：

# %%
# %%vuepy_run --plugins vpanel --show-code
# <template>
#   <PnTerminal :height="300"
#              command="python -c 'print(\"Hello from Python!\")'" />
# </template>
# <script lang='py'>
# from vuepy import ref
# </script>
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1ca4f71c-7007-4699-9eca-565522762e0b'>
#   <div id="e389c52e-4f7a-4baa-ae12-b27e7f3d4b41" data-root-id="1ca4f71c-7007-4699-9eca-565522762e0b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4490586a-6d56-4dcb-a344-866546a71c83":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1ca4f71c-7007-4699-9eca-565522762e0b"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"534c36c9-7606-4d65-b6a3-7bb7537a734c","attributes":{"plot_id":"1ca4f71c-7007-4699-9eca-565522762e0b","comm_id":"44dd623e921b4acc9c9bd7a01790fb27","client_comm_id":"114ddc76ee674e3a81cbbbf6f709b5d2"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"4490586a-6d56-4dcb-a344-866546a71c83","roots":{"1ca4f71c-7007-4699-9eca-565522762e0b":"e389c52e-4f7a-4baa-ae12-b27e7f3d4b41"},"root_ids":["1ca4f71c-7007-4699-9eca-565522762e0b"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined) && ( root.Terminal !== undefined|| root.xtermjs !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# {"vue": "<template>\n  <PnTerminal :height=\"300\" \n             command=\"python -c 'print(\\\"Hello from Python!\\\")'\" />\n</template>\n<script lang='py'>\nfrom vuepy import ref\n</script>\n", "setup": ""}
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_cell_magic('vuepy_run', '--plugins vpanel --show-code', '<template>\n  <PnTerminal :height="300" \n             command="python -c \'print(\\"Hello from Python!\\")\'" />\n</template>\n<script lang=\'py\'>\nfrom vuepy import ref\n</script>\n')
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2541 with self.builtin_trap:
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
#    2545 # The code below prevents the output from being displayed
#    2546 # when using magics with decorator @output_can_be_silenced
#    2547 # when the last Python token in the expression is a ';'.
#    2548 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/utils/magic.py:282, in vuepy_run(vue_file, cell)
#     275 if args.show_code:
#     276     # sfc_file_comment = f'<!-- {sfc_file_path} -->\n'
#     277     print(json.dumps({
#     278         'vue': cell,
#     279         'setup': '',
#     280     }))
# --> 282 return app.mount()
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/runtime/core/api_create_app.py:184, in App.mount(self, el)
#     182 def mount(self, el=None):
#     183     # self._call_if_callable(self.options.before_mount)
# --> 184     self.render()
#     185     # self._call_if_callable(self.options.mounted)
#     186
#     187     # self.document.body_node.appendChild(self.dom)
#     188     self.document.body.append(self.dom)
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/runtime/core/api_create_app.py:132, in App.render(self)
#     129     raise ValueError(f"render failed, root_component type {type(self.root_component)}.")
#     131 # self.dom = self.options.render({}, self._props, self._data)
# --> 132 self.dom = self.root_component.render({}, {}, {})
#     133 # with self.options.el:
#     134 # with self._container:
#     135 #     clear_output(True)
#     136 #     display(self.dom)
#     137 logger.info('App render end.')
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/compiler_sfc/sfc_codegen.py:243, in SFC.render(self, ctx, props, setup_returned)
#     241     else:
#     242         from vuepy.compiler_sfc.template_compiler import DomCompiler
# --> 243         dom = DomCompiler(self, self.app).compile(self.template)
#     245 # self.sfc_widget_node.children = [dom]
#     246 self.sfc_widget_node.replace_children([dom])
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/compiler_sfc/template_compiler.py:311, in DomCompiler.compile(self, html)
#     309 except Exception as e:
#     310     self._compile_traceback_info = self._compile_traceback(e)
# --> 311     raise e
#     313 if len(self.widgets.children) == 1:
#     314     return self.widgets.children[0]
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/compiler_sfc/template_compiler.py:308, in DomCompiler.compile(self, html)
#     306 self.html_lines = [line for line in html.splitlines()]
#     307 try:
# --> 308     self.feed(html)
#     309 except Exception as e:
#     310     self._compile_traceback_info = self._compile_traceback(e)
#
# File ~/miniforge3/envs/textgen/lib/python3.10/html/parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File ~/miniforge3/envs/textgen/lib/python3.10/html/parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File ~/miniforge3/envs/textgen/lib/python3.10/html/parser.py:342, in HTMLParser.parse_starttag(self, i)
#     339     return endpos
#     340 if end.endswith('/>'):
#     341     # XHTML-style empty tag: <span attr="value" />
# --> 342     self.handle_startendtag(tag, attrs)
#     343 else:
#     344     self.handle_starttag(tag, attrs)
#
# File ~/miniforge3/envs/textgen/lib/python3.10/html/parser.py:427, in HTMLParser.handle_startendtag(self, tag, attrs)
#     425 def handle_startendtag(self, tag, attrs):
#     426     self.handle_starttag(tag, attrs)
# --> 427     self.handle_endtag(tag)
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/compiler_sfc/template_compiler.py:244, in DomCompiler.handle_endtag(self, tag)
#     241 # ./_gen_element
#     243 node = self.parent_node_stack.pop()
# --> 244 _gen_element(node)
#     245 if node.for_processed:
#     246     self.v_for_stack.pop()
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/compiler_sfc/template_compiler.py:223, in DomCompiler.handle_endtag.<locals>._gen_element(_node)
#     220         _gen_element(_node)
#     221     return
# --> 223 widget = self._gen_widget(_node, _node.v_for_scopes)
#     224 widget._vtag = widget.__class__.__name__
#     225 # not v-for
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/compiler_sfc/template_compiler.py:67, in DomCompiler._gen_widget(self, node, for_scope)
#      65 ns = VueCompNamespace(self.vm.to_ns(), self.vm.to_ns(), local_vars)
#      66 if self.vm.component(node.tag):
# ---> 67     widget = VueCompCodeGen.gen(node, self.vm, ns, self.app)
#      68 else:
#      69     widget = VueHtmlCompCodeGen.gen(node, ns, self.app)
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/compiler_sfc/template_codegen.py:77, in VueCompCodeGen.gen(cls, node, vm, ns, app)
#      75     return dummy
#      76 else:
# ---> 77     return cls._gen(comp_ast, node.children, vm, ns, app)
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/vuepy/compiler_sfc/template_codegen.py:124, in VueCompCodeGen._gen(cls, comp_ast, children, vm, ns, app)
#     121 else:
#     122     component = component_cls()
# --> 124 widget: INode = component.render(ctx, props, {})
#     126 if comp_ast.tag == 'slot' and isinstance(vm, SFC):
#     127     _slot_name = comp_ast.kwargs.get('name', 'default')
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/panel_vuepy/core.py:111, in VPanelComponent.render(self, ctx, props, setup_returned)
#     109 # process slots
#     110 self._convert_slot_nodes_to_widgets(ctx.get('slots'))
# --> 111 widget = self._render(ctx, attrs, props, params, setup_returned)
#     113 # Inject on_change support
#     114 self._inject_on_change_register(widget)
#
# File ~/proj/bb/url2io.com/open_sesame/nb_llm/pyvue/src/panel_vuepy/comps.py:969, in Terminal._render(self, ctx, attrs, props, params, setup_returned)
#     967 def _render(self, ctx, attrs, props, params, setup_returned):
#     968     _params = {**props, **attrs, **params}
# --> 969     return pn.widgets.Terminal(**_params)
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/panel/widgets/terminal.py:270, in Terminal.__init__(self, output, **params)
#     268 params['_output'] = output = output or ''
#     269 params['clear'] = self._clear
# --> 270 super().__init__(output=output, **params)
#     271 self._subprocess = None
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/panel/widgets/base.py:151, in Widget.__init__(self, **params)
#     149 else:
#     150     self._param_pane = None
# --> 151 super().__init__(**params)
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/panel/reactive.py:639, in Reactive.__init__(self, refs, **params)
#     637     if refs:
#     638         param.bind(self._sync_refs, *refs, watch=True)
# --> 639 super().__init__(**params)
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/panel/reactive.py:129, in Syncable.__init__(self, **params)
#     127 def __init__(self, **params):
#     128     self._themer = None
# --> 129     super().__init__(**params)
#     131     # Useful when updating model properties which trigger potentially
#     132     # recursive events
#     133     self._updating = False
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/panel/viewable.py:732, in Viewable.__init__(self, **params)
#     730 def __init__(self, **params):
#     731     hooks = params.pop('hooks', [])
# --> 732     super().__init__(**params)
#     733     self._hooks = hooks
#     735     if self.loading:
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/panel/viewable.py:563, in Renderable.__init__(self, **params)
#     561 self._comms = {}
#     562 self._kernels = {}
# --> 563 super().__init__(**params)
#     564 self._found_links = set()
#     565 self._logger = logging.getLogger(f'{__name__}.{type(self).__name__}')
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/panel/viewable.py:308, in Layoutable.__init__(self, **params)
#     306 if 'design' not in params and self.param.design.default is None:
#     307     params['design'] = config.design
# --> 308 super().__init__(**params)
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/param/parameterized.py:4325, in Parameterized.__init__(self, **params)
#    4323 if self.param.name.default == self.__class__.__name__:
#    4324     self.param._generate_name()
# -> 4325 refs, deps = self.param._setup_params(**params)
#    4326 object_count += 1
#    4328 self._param__private.initialized = True
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/param/parameterized.py:1697, in as_uninitialized.<locals>.override_initialization(self_, *args, **kw)
#    1695 original_initialized = parameterized_instance._param__private.initialized
#    1696 parameterized_instance._param__private.initialized = False
# -> 1697 ret = fn(self_, *args, **kw)
#    1698 parameterized_instance._param__private.initialized = original_initialized
#    1699 return ret
#
# File ~/miniforge3/envs/textgen/lib/python3.10/site-packages/param/parameterized.py:1948, in Parameters._setup_params(self_, **params)
#    1946 desc = self_.cls.get_param_descriptor(name)[0] # pylint: disable-msg=E1101
#    1947 if not desc:
# -> 1948     raise TypeError(
#    1949         f"{self.__class__.__name__}.__init__() got an unexpected "
#    1950         f"keyword argument {name!r}"
#    1951     )
#    1953 pobj = objects.get(name)
#    1954 if pobj is None or not pobj.allow_refs:
#    1955     # Until Parameter.allow_refs=True by default we have to
#    1956     # speculatively evaluate a values to check whether they
#    1957     # contain a reference and warn the user that the
#    1958     # behavior may change in future.
#
# TypeError: Terminal.__init__() got an unexpected keyword argument 'command'

# %% [markdown]
# ## 自定义参数
#
# 可以设置各种终端参数，如字体大小、是否显示光标等：

# %%
# %%vuepy_run --plugins vpanel --show-code
# <template>
#   <PnTerminal height="300px"
#              :terminal_config="{
#                'cursorBlink': true,
#                'fontSize': 18,
#                'theme': {
#                  'background': '#2b2b2b',
#                  'foreground': '#f8f8f8'
#                }
#              }" />
# </template>
# <script lang='py'>
# from vuepy import ref
# </script>

# %% [markdown]
# ## 交互处理
#
# 终端还可以通过命令随时更新：

# %%
# %%vuepy_run --plugins vpanel --show-code
# <template>
#   <PnRow>
#     <PnButton name="运行ls命令" @click="run_ls" />
#     <PnButton name="清空终端" @click="clear_term" />
#   </PnRow>
#   <PnRow>
#     <PnTerminal height="300px" ref="terminal" />
#   </PnRow>
# </template>
# <script lang='py'>
# from vuepy import ref
#
# terminal = ref(None)
#
# def run_ls():
#     if terminal.value:
#         terminal.value.write("ls\n")
#
# def clear_term():
#     if terminal.value:
#         terminal.value.clear()
# </script>

# %% [markdown]
# ## 使用环境变量
#
# 可以设置终端的环境变量：

# %%
# %%vuepy_run --plugins vpanel --show-code
# <template>
#   <PnTerminal height="300px"
#              command="echo $CUSTOM_VAR"
#              :env="{
#                'CUSTOM_VAR': '这是一个自定义环境变量'
#              }" />
# </template>
# <script lang='py'>
# from vuepy import ref
# </script>

# %% [markdown]
# ## API
#
# ### 属性
#
# | 属性名          | 说明                 | 类型                          | 默认值 |
# | -------------- | ------------------- | ----------------------------- | ------ |
# | command        | 终端启动时要执行的命令 | ^[str]                        | None   |
# | env            | 终端执行环境的环境变量 | ^[dict]                       | None   |
# | options        | 传递给终端后端的选项   | ^[dict]                       | None   |
# | terminal_config | 传递给xterm.js的选项  | ^[dict]                       | {}     |
# | value          | 终端目前的输出内容     | ^[str]                        | ""     |
# | disabled       | 是否禁用组件          | ^[bool]                       | False  |
# | name           | 组件标题              | ^[str]                        | ""     |
#
# ### Events
#
# | 事件名 | 说明                  | 类型                                   |
# | ---   | ---                  | ---                                    |
# | change | 当终端内容变化时触发   | ^[Callable]`(event: dict) -> None` |
#
# ### Slots
#
# | 插槽名   | 说明               |
# | ---     | ---               |
# |         |                   |
#
# ### 方法
#
# | 方法名 | 说明 | 类型 |
# | ----- | ---- | ---- |
# | clear | 清空终端内容 | ^[Callable]`() -> None` |
# | write | 向终端写入内容 | ^[Callable]`(content: str) -> None` |

# %%
##ignore
import panel as pn
pn.extension()

terminal = pn.widgets.Terminal(height=300, options={'shell': True})
terminal
